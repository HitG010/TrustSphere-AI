# %%
import networkx as nx

def hetero_to_networkx(data):
    G = nx.Graph()
    node_id_map = {}
    current_id = 0

    for ntype in data.node_types:
        num_nodes = data[ntype].num_nodes
        for i in range(num_nodes):
            global_id = current_id
            G.add_node(global_id, node_type=ntype, orig_id=i)
            node_id_map[(ntype, i)] = global_id
            current_id += 1

    for src_type, rel, dst_type in data.edge_types:
        edge_index = data[(src_type, rel, dst_type)].edge_index
        for src, dst in zip(edge_index[0].tolist(), edge_index[1].tolist()):
            src_global = node_id_map[(src_type, src)]
            dst_global = node_id_map[(dst_type, dst)]
            G.add_edge(src_global, dst_global, edge_type=rel)

    return G, node_id_map

# %%
import community.community_louvain as community_louvain

data = torch.load('../hetero_graph.pt', weights_only=False)  # Load your HeteroData object

G, node_id_map = hetero_to_networkx(data)

# Louvain community detection
partition = community_louvain.best_partition(G)

# Convert to: community_id → list of nodes
from collections import defaultdict
communities = defaultdict(list)
for node, comm_id in partition.items():
    communities[comm_id].append(node)

print(f"Detected {len(communities)} communities.")
# Out:
# Detected 201 communities.

# %%
import igraph as ig
import leidenalg

def networkx_to_igraph(G):
    mapping = {node: i for i, node in enumerate(G.nodes())}
    G_ig = ig.Graph()
    G_ig.add_vertices(len(mapping))

    edges = [(mapping[u], mapping[v]) for u, v in G.edges()]
    G_ig.add_edges(edges)

    return G_ig, mapping

G_ig, mapping = networkx_to_igraph(G)
partition = leidenalg.find_partition(G_ig, leidenalg.ModularityVertexPartition)

# Map back community members
communities = []
for part in partition:
    community_nodes = [list(G.nodes())[i] for i in part]
    communities.append(community_nodes)

print(f"Detected {len(communities)} communities.")
# Out:
# Detected 202 communities.

# %%
def analyze_community(community_nodes, G):
    types = [G.nodes[n]['ntype'] for n in community_nodes]
    from collections import Counter
    print("Composition:", Counter(types))
    return types

# Example: analyze top 5 communities
for i, comm in enumerate(list(communities.values())[:5]):
    print(f"\nCommunity {i}: size {len(comm)}")
    analyze_community(comm, G)
# Out:
# Community 0: size 71
# Composition: Counter({'reviewer': 35, 'review': 35, 'product': 1})
#
# Community 1: size 5
# Composition: Counter({'product': 1, 'reviewer': 1, 'brand': 1, 'category': 1, 'review': 1})
#
# Community 2: size 174
# Composition: Counter({'review': 86, 'reviewer': 84, 'product': 2, 'brand': 1, 'category': 1})
#
# Community 3: size 505
# Composition: Counter({'review': 253, 'reviewer': 251, 'product': 1})
#
# Community 4: size 166
# Composition: Counter({'review': 78, 'reviewer': 75, 'product': 8, 'brand': 4, 'category': 1})

# %%
import matplotlib.pyplot as plt

pos = nx.spring_layout(G, seed=42)
colors = [partition[n] for n in G.nodes()]
nx.draw(G, pos, node_color=colors, node_size=20, with_labels=False)
plt.show()

# %% [markdown]
# Scoring Function
# You can define a suspiciousness score S(c) for community c as a weighted sum of the following metrics:
#
# S(c) = α * Density(c) + β * Reviewer-to-Product Ratio + γ * Edge Concentration + δ * Time Burst Score
# Where:
#
# Metric	Description	Suspicious if...
# - Density	#actual edges / #possible edges within community ->	High
# - Reviewer-to-Product Ratio	Many reviewers → few products ->	High
# - Edge Concentration	Many reviewers reviewing same products ->	High
# - Time Burst	Most reviews in few days ->	High

# %%
from collections import defaultdict
import networkx as nx

# G: networkx graph with 'node_type' attribute
# partition: dict[node_id] -> community_id
community_nodes = defaultdict(list)
for node_id, comm_id in partition.items():
    community_nodes[comm_id].append(node_id)

def compute_suspiciousness(G, community_nodes):
    scores = {}
    for comm_id, nodes in community_nodes.items():
        subG = G.subgraph(nodes)
        num_nodes = subG.number_of_nodes()
        num_edges = subG.number_of_edges()

        # Density
        max_edges = num_nodes * (num_nodes - 1) / 2
        density = num_edges / max_edges if max_edges > 0 else 0

        # Reviewer-to-product ratio
        reviewers = [n for n in nodes if G.nodes[n]['node_type'] == 'reviewer']
        products = [n for n in nodes if G.nodes[n]['node_type'] == 'product']
        rev_to_prod_ratio = len(reviewers) / (len(products) + 1e-5)

        # Edge concentration: how many reviewers review the same product
        product_review_count = defaultdict(int)
        for u, v in subG.edges():
            if G.nodes[u]['node_type'] == 'reviewer' and G.nodes[v]['node_type'] == 'product':
                product_review_count[v] += 1
            elif G.nodes[v]['node_type'] == 'reviewer' and G.nodes[u]['node_type'] == 'product':
                product_review_count[u] += 1
        if product_review_count:
            avg_review_per_product = sum(product_review_count.values()) / len(product_review_count)
        else:
            avg_review_per_product = 0

        # Final suspiciousness score
        score = 0.5 * density + 0.3 * rev_to_prod_ratio + 0.2 * avg_review_per_product
        scores[comm_id] = score

    return scores

# Usage
suspiciousness_scores = compute_suspiciousness(G, community_nodes)
sorted_sus = sorted(suspiciousness_scores.items(), key=lambda x: x[1], reverse=True)
for comm_id, score in sorted_sus[:10]:
    print(f"Community {comm_id}: Suspiciousness Score = {score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 7
#       4 # G: networkx graph with 'node_type' attribute
#       5 # partition: dict[node_id] -> community_id
#       6 community_nodes = defaultdict(list)
# ----> 7 for node_id, comm_id in partition.items():
#       8     community_nodes[comm_id].append(node_id)
#      10 def compute_suspiciousness(G, community_nodes):
#
# AttributeError: 'ModularityVertexPartition' object has no attribute 'items'

# %%
for comm_id, score in sorted_sus:
    print(f"Community {comm_id}: Suspiciousness Score = {score:.4f}")
# Out:
# Community 20: Suspiciousness Score = 369.2967
# Community 7: Suspiciousness Score = 220.1985
# Community 12: Suspiciousness Score = 191.6989
# Community 35: Suspiciousness Score = 187.7989
# Community 23: Suspiciousness Score = 148.3498
# Community 22: Suspiciousness Score = 139.4997
# Community 21: Suspiciousness Score = 119.1001
# Community 17: Suspiciousness Score = 114.9001
# Community 25: Suspiciousness Score = 109.2003
# Community 33: Suspiciousness Score = 108.6003
# Community 32: Suspiciousness Score = 93.6007
# Community 15: Suspiciousness Score = 81.0010
# Community 3: Suspiciousness Score = 75.3012
# Community 6: Suspiciousness Score = 70.5014
# Community 10: Suspiciousness Score = 70.2014
# Community 41: Suspiciousness Score = 63.0017
# Community 13: Suspiciousness Score = 36.7509
# Community 34: Suspiciousness Score = 35.4039
# Community 24: Suspiciousness Score = 33.6041
# Community 18: Suspiciousness Score = 33.0042
# Community 37: Suspiciousness Score = 32.7042
# Community 9: Suspiciousness Score = 27.4526
# Community 19: Suspiciousness Score = 26.1054
# Community 36: Suspiciousness Score = 25.5056
# Community 40: Suspiciousness Score = 18.9076
# Community 38: Suspiciousness Score = 18.1540
# Community 2: Suspiciousness Score = 12.6057
# Community 31: Suspiciousness Score = 10.8132
# Community 0: Suspiciousness Score = 10.5140
# Community 39: Suspiciousness Score = 10.3567
# Community 30: Suspiciousness Score = 9.9142
# Community 28: Suspiciousness Score = 6.9203
# Community 29: Suspiciousness Score = 6.9203
# Community 8: Suspiciousness Score = 5.7082
# Community 11: Suspiciousness Score = 5.6043
# Community 26: Suspiciousness Score = 4.5303
# Community 5: Suspiciousness Score = 4.3265
# Community 16: Suspiciousness Score = 4.2333
# Community 14: Suspiciousness Score = 2.8187
# Community 27: Suspiciousness Score = 1.0111
# Community 1: Suspiciousness Score = 0.5000
# Community 42: Suspiciousness Score = 0.0000
# Community 43: Suspiciousness Score = 0.0000
# Community 44: Suspiciousness Score = 0.0000
# Community 45: Suspiciousness Score = 0.0000
# Community 46: Suspiciousness Score = 0.0000
# Community 47: Suspiciousness Score = 0.0000
# Community 48: Suspiciousness Score = 0.0000
# Community 49: Suspiciousness Score = 0.0000
# Community 50: Suspiciousness Score = 0.0000
# Community 51: Suspiciousness Score = 0.0000
# Community 52: Suspiciousness Score = 0.0000
# Community 53: Suspiciousness Score = 0.0000
# Community 54: Suspiciousness Score = 0.0000
# Community 55: Suspiciousness Score = 0.0000
# Community 56: Suspiciousness Score = 0.0000
# Community 57: Suspiciousness Score = 0.0000
# Community 58: Suspiciousness Score = 0.0000
# Community 59: Suspiciousness Score = 0.0000
# Community 60: Suspiciousness Score = 0.0000
# Community 61: Suspiciousness Score = 0.0000
# Community 62: Suspiciousness Score = 0.0000
# Community 63: Suspiciousness Score = 0.0000
# Community 64: Suspiciousness Score = 0.0000
# Community 65: Suspiciousness Score = 0.0000
# Community 66: Suspiciousness Score = 0.0000
# Community 67: Suspiciousness Score = 0.0000
# Community 68: Suspiciousness Score = 0.0000
# Community 69: Suspiciousness Score = 0.0000
# Community 70: Suspiciousness Score = 0.0000
# Community 71: Suspiciousness Score = 0.0000
# Community 72: Suspiciousness Score = 0.0000
# Community 73: Suspiciousness Score = 0.0000
# Community 74: Suspiciousness Score = 0.0000
# Community 75: Suspiciousness Score = 0.0000
# Community 76: Suspiciousness Score = 0.0000
# Community 77: Suspiciousness Score = 0.0000
# Community 78: Suspiciousness Score = 0.0000
# Community 79: Suspiciousness Score = 0.0000
# Community 80: Suspiciousness Score = 0.0000
# Community 81: Suspiciousness Score = 0.0000
# Community 82: Suspiciousness Score = 0.0000
# Community 83: Suspiciousness Score = 0.0000
# Community 84: Suspiciousness Score = 0.0000
# Community 85: Suspiciousness Score = 0.0000
# Community 86: Suspiciousness Score = 0.0000
# Community 87: Suspiciousness Score = 0.0000
# Community 88: Suspiciousness Score = 0.0000
# Community 89: Suspiciousness Score = 0.0000
# Community 90: Suspiciousness Score = 0.0000
# Community 91: Suspiciousness Score = 0.0000
# Community 92: Suspiciousness Score = 0.0000
# Community 93: Suspiciousness Score = 0.0000
# Community 94: Suspiciousness Score = 0.0000
# Community 95: Suspiciousness Score = 0.0000
# Community 96: Suspiciousness Score = 0.0000
# Community 97: Suspiciousness Score = 0.0000
# Community 98: Suspiciousness Score = 0.0000
# Community 99: Suspiciousness Score = 0.0000
# Community 100: Suspiciousness Score = 0.0000
# Community 101: Suspiciousness Score = 0.0000
# Community 102: Suspiciousness Score = 0.0000
# Community 103: Suspiciousness Score = 0.0000
# Community 104: Suspiciousness Score = 0.0000
# Community 105: Suspiciousness Score = 0.0000
# Community 106: Suspiciousness Score = 0.0000
# Community 107: Suspiciousness Score = 0.0000
# Community 108: Suspiciousness Score = 0.0000
# Community 109: Suspiciousness Score = 0.0000
# Community 110: Suspiciousness Score = 0.0000
# Community 111: Suspiciousness Score = 0.0000
# Community 112: Suspiciousness Score = 0.0000
# Community 113: Suspiciousness Score = 0.0000
# Community 114: Suspiciousness Score = 0.0000
# Community 115: Suspiciousness Score = 0.0000
# Community 116: Suspiciousness Score = 0.0000
# Community 117: Suspiciousness Score = 0.0000
# Community 118: Suspiciousness Score = 0.0000
# Community 119: Suspiciousness Score = 0.0000
# Community 120: Suspiciousness Score = 0.0000
# Community 121: Suspiciousness Score = 0.0000
# Community 122: Suspiciousness Score = 0.0000
# Community 123: Suspiciousness Score = 0.0000
# Community 124: Suspiciousness Score = 0.0000
# Community 125: Suspiciousness Score = 0.0000
# Community 126: Suspiciousness Score = 0.0000
# Community 127: Suspiciousness Score = 0.0000
# Community 128: Suspiciousness Score = 0.0000
# Community 129: Suspiciousness Score = 0.0000
# Community 130: Suspiciousness Score = 0.0000
# Community 131: Suspiciousness Score = 0.0000
# Community 132: Suspiciousness Score = 0.0000
# Community 133: Suspiciousness Score = 0.0000
# Community 134: Suspiciousness Score = 0.0000
# Community 135: Suspiciousness Score = 0.0000
# Community 136: Suspiciousness Score = 0.0000
# Community 137: Suspiciousness Score = 0.0000
# Community 138: Suspiciousness Score = 0.0000
# Community 139: Suspiciousness Score = 0.0000
# Community 140: Suspiciousness Score = 0.0000
# Community 141: Suspiciousness Score = 0.0000
# Community 142: Suspiciousness Score = 0.0000
# Community 143: Suspiciousness Score = 0.0000
# Community 144: Suspiciousness Score = 0.0000
# Community 145: Suspiciousness Score = 0.0000
# Community 146: Suspiciousness Score = 0.0000
# Community 147: Suspiciousness Score = 0.0000
# Community 148: Suspiciousness Score = 0.0000
# Community 149: Suspiciousness Score = 0.0000
# Community 150: Suspiciousness Score = 0.0000
# Community 151: Suspiciousness Score = 0.0000
# Community 152: Suspiciousness Score = 0.0000
# Community 153: Suspiciousness Score = 0.0000
# Community 154: Suspiciousness Score = 0.0000
# Community 155: Suspiciousness Score = 0.0000
# Community 156: Suspiciousness Score = 0.0000
# Community 157: Suspiciousness Score = 0.0000
# Community 158: Suspiciousness Score = 0.0000
# Community 159: Suspiciousness Score = 0.0000
# Community 160: Suspiciousness Score = 0.0000
# Community 161: Suspiciousness Score = 0.0000
# Community 162: Suspiciousness Score = 0.0000
# Community 163: Suspiciousness Score = 0.0000
# Community 164: Suspiciousness Score = 0.0000
# Community 165: Suspiciousness Score = 0.0000
# Community 166: Suspiciousness Score = 0.0000
# Community 167: Suspiciousness Score = 0.0000
# Community 168: Suspiciousness Score = 0.0000
# Community 169: Suspiciousness Score = 0.0000
# Community 170: Suspiciousness Score = 0.0000
# Community 171: Suspiciousness Score = 0.0000
# Community 172: Suspiciousness Score = 0.0000
# Community 173: Suspiciousness Score = 0.0000
# Community 174: Suspiciousness Score = 0.0000
# Community 175: Suspiciousness Score = 0.0000
# Community 176: Suspiciousness Score = 0.0000
# Community 177: Suspiciousness Score = 0.0000
# Community 178: Suspiciousness Score = 0.0000
# Community 179: Suspiciousness Score = 0.0000
# Community 180: Suspiciousness Score = 0.0000
# Community 181: Suspiciousness Score = 0.0000
# Community 182: Suspiciousness Score = 0.0000
# Community 183: Suspiciousness Score = 0.0000
# Community 184: Suspiciousness Score = 0.0000
# Community 185: Suspiciousness Score = 0.0000
# Community 186: Suspiciousness Score = 0.0000
# Community 187: Suspiciousness Score = 0.0000
# Community 188: Suspiciousness Score = 0.0000
# Community 189: Suspiciousness Score = 0.0000
# Community 190: Suspiciousness Score = 0.0000
# Community 191: Suspiciousness Score = 0.0000
# Community 192: Suspiciousness Score = 0.0000
# Community 193: Suspiciousness Score = 0.0000
# Community 194: Suspiciousness Score = 0.0000
# Community 195: Suspiciousness Score = 0.0000
# Community 196: Suspiciousness Score = 0.0000
# Community 197: Suspiciousness Score = 0.0000
# Community 198: Suspiciousness Score = 0.0000
# Community 199: Suspiciousness Score = 0.0000
# Community 200: Suspiciousness Score = 0.0000
# Community 4: Suspiciousness Score = 0.0000

# %%
import matplotlib.pyplot as plt

colors = {'reviewer': 'red', 'product': 'blue', 'review': 'green',
          'brand': 'orange', 'category': 'purple'}
node_colors = [colors[G.nodes[n]['node_type']] for n in G.nodes()]
nx.draw(G, node_color=node_colors, with_labels=False, node_size=30)
plt.show()
